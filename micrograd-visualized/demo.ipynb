# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from micrograd.engine import Value
from micrograd.nn import Neuron, Layer, MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %%
from sklearn.datasets import make_moons, make_blobs
X, y = make_moons(n_samples=100, noise=0.1)

y = y*2 - 1 # make y be -1 or 1
# visualize in 2D
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
# initialize a model 
model = MLP(2, [16, 16, 1]) # 2-layer neural network
print(model)
print("number of parameters", len(model.parameters()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # initialize a model
# ----> 2 model = MLP(2, [16, 16, 1]) # 2-layer neural network
#       3 print(model)
#       4 print("number of parameters", len(model.parameters()))
#
# File ~/Documents/GitHub/DL-Projects/micrograd-visualized/micrograd/nn.py:45, in MLP.__init__(self, nin, nouts)
#      43 def __init__(self, nin, nouts):
#      44     sz = [nin] + nouts
# ---> 45     self.layers = [Layer(sz[i], sz[i+1], nonlin=i != len(nouts)-1) for i in range(len(nouts))]
#
# File ~/Documents/GitHub/DL-Projects/micrograd-visualized/micrograd/nn.py:29, in Layer.__init__(self, nin, nout, **kwargs)
#      28 def __init__(self, nin, nout, **kwargs):
# ---> 29     self.neurons = [Neuron(min, **kwargs) for _ in range(nout)]
#
# File ~/Documents/GitHub/DL-Projects/micrograd-visualized/micrograd/nn.py:14, in Neuron.__init__(self, nin, nonlin)
#      13 def __init__(self, nin, nonlin=True):
# ---> 14     self.w = [Value(random.uniform(-1,1)) for _ in range(nin)]
#      15     self.b = [Value(0)]
#      16     self.nonlin = nonlin
#
# TypeError: 'builtin_function_or_method' object cannot be interpreted as an integer
